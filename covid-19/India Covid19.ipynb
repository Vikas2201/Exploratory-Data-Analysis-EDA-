# %% [markdown]
# # Importing the required libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # loading data set

# %%
df = pd.read_csv("covid.csv")

# %%
# To display the top 5 rows
df.head()
# Out:
#   iso_code location        date  total_cases  new_cases  total_deaths  \
# 0      ABW    Aruba  2020-03-13            2          2             0
# 1      ABW    Aruba  2020-03-20            4          2             0
# 2      ABW    Aruba  2020-03-24           12          8             0
# 3      ABW    Aruba  2020-03-25           17          5             0
# 4      ABW    Aruba  2020-03-26           19          2             0
#
#    new_deaths  total_cases_per_million  new_cases_per_million  \
# 0           0                   18.733                 18.733
# 1           0                   37.465                 18.733
# 2           0                  112.395                 74.930
# 3           0                  159.227                 46.831
# 4           0                  177.959                 18.733
#
#    total_deaths_per_million  ...  aged_65_older  aged_70_older  \
# 0                       0.0  ...         13.085          7.452
# ...

# %%
# To display the bottom 5 rows
df.tail()
# Out:
#       iso_code       location        date  total_cases  new_cases  \
# 19491      NaN  International  2020-02-28          705          0
# 19492      NaN  International  2020-02-29          705          0
# 19493      NaN  International  2020-03-01          705          0
# 19494      NaN  International  2020-03-02          705          0
# 19495      NaN  International  2020-03-10          696         -9
#
#        total_deaths  new_deaths  total_cases_per_million  \
# 19491             4           0                      NaN
# 19492             6           2                      NaN
# 19493             6           0                      NaN
# 19494             6           0                      NaN
# 19495             7           1                      NaN
#
#        new_cases_per_million  total_deaths_per_million  ...  aged_65_older  \
# 19491                    NaN                       NaN  ...            NaN
# ...

# %%
#looking at the shape
df.shape
# Out:
# (19496, 32)

# %% [markdown]
# we have 19496 rows and 32 columns
# ___________________________________

# %% [markdown]
# # looking the information about data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19496 entries, 0 to 19495
# Data columns (total 32 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   iso_code                         19432 non-null  object
#  1   location                         19496 non-null  object
#  2   date                             19496 non-null  object
#  3   total_cases                      19496 non-null  int64
#  4   new_cases                        19496 non-null  int64
#  5   total_deaths                     19496 non-null  int64
#  6   new_deaths                       19496 non-null  int64
#  7   total_cases_per_million          19119 non-null  float64
#  8   new_cases_per_million            19119 non-null  float64
#  9   total_deaths_per_million         19119 non-null  float64
#  10  new_deaths_per_million           19119 non-null  float64
#  11  total_tests                      5164 non-null   float64
# ...

# %% [markdown]
# # checking if columns have NAN values

# %%
#checking if columns have NAN values
df.isnull().any()
# Out:
# iso_code                            True
# location                           False
# date                               False
# total_cases                        False
# new_cases                          False
# total_deaths                       False
# new_deaths                         False
# total_cases_per_million             True
# new_cases_per_million               True
# total_deaths_per_million            True
# new_deaths_per_million              True
# total_tests                         True
# new_tests                           True
# total_tests_per_thousand            True
# new_tests_per_thousand              True
# new_tests_smoothed                  True
# new_tests_smoothed_per_thousand     True
# tests_units                         True
# stringency_index                    True
# population                          True
# population_density                  True
# median_age                          True
# aged_65_older                       True
# ...

# %%
#getting the sum of nan values
df.isnull().sum()
# Out:
# iso_code                              64
# location                               0
# date                                   0
# total_cases                            0
# new_cases                              0
# total_deaths                           0
# new_deaths                             0
# total_cases_per_million              377
# new_cases_per_million                377
# total_deaths_per_million             377
# new_deaths_per_million               377
# total_tests                        14332
# new_tests                          14904
# total_tests_per_thousand           14332
# new_tests_per_thousand             14904
# new_tests_smoothed                 13866
# new_tests_smoothed_per_thousand    13866
# tests_units                        13267
# stringency_index                    4500
# population                            64
# population_density                   850
# median_age                          1743
# aged_65_older                       1980
# ...

# %% [markdown]
# # looking differnet location

# %%
df["location"].value_counts()
# Out:
# Finland           146
# Russia            146
# Italy             146
# Lithuania         146
# China             146
#                  ...
# Yemen              45
# Western Sahara     29
# Tajikistan         24
# Comoros            23
# Lesotho            10
# Name: location, Length: 212, dtype: int64

# %% [markdown]
# ### India Case

# %%
#getting india case form data set
data = df[df["location"] == "India"]

# %%
# To display the top 5 rows
data.head()
# Out:
#      iso_code location        date  total_cases  new_cases  total_deaths  \
# 8379      IND    India  2019-12-31            0          0             0
# 8380      IND    India  2020-01-01            0          0             0
# 8381      IND    India  2020-01-02            0          0             0
# 8382      IND    India  2020-01-03            0          0             0
# 8383      IND    India  2020-01-04            0          0             0
#
#       new_deaths  total_cases_per_million  new_cases_per_million  \
# 8379           0                      0.0                    0.0
# 8380           0                      0.0                    0.0
# 8381           0                      0.0                    0.0
# 8382           0                      0.0                    0.0
# 8383           0                      0.0                    0.0
#
#       total_deaths_per_million  ...  aged_65_older  aged_70_older  \
# ...

# %%
# To display the bottom 5 rows
data.tail()
# Out:
#      iso_code location        date  total_cases  new_cases  total_deaths  \
# 8519      IND    India  2020-05-20       106750       5611          3303
# 8520      IND    India  2020-05-21       112359       5609          3435
# 8521      IND    India  2020-05-22       118447       6088          3583
# 8522      IND    India  2020-05-23       125101       6654          3720
# 8523      IND    India  2020-05-24       131868       6767          3867
#
#       new_deaths  total_cases_per_million  new_cases_per_million  \
# 8519         140                   77.355                  4.066
# 8520         132                   81.419                  4.064
# 8521         148                   85.831                  4.412
# 8522         137                   90.653                  4.822
# 8523         147                   95.556                  4.904
#
#       total_deaths_per_million  ...  aged_65_older  aged_70_older  \
# ...

# %%
#looking at the shape
data.shape
# Out:
# (145, 32)

# %% [markdown]
# we have 145 rows and 32 columns in India Covid19 data set

# %% [markdown]
# ### looking the information about data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 145 entries, 8379 to 8523
# Data columns (total 32 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   iso_code                         145 non-null    object
#  1   location                         145 non-null    object
#  2   date                             145 non-null    object
#  3   total_cases                      145 non-null    int64
#  4   new_cases                        145 non-null    int64
#  5   total_deaths                     145 non-null    int64
#  6   new_deaths                       145 non-null    int64
#  7   total_cases_per_million          145 non-null    float64
#  8   new_cases_per_million            145 non-null    float64
#  9   total_deaths_per_million         145 non-null    float64
#  10  new_deaths_per_million           145 non-null    float64
#  11  total_tests                      60 non-null     float64
# ...

# %% [markdown]
# # Dropping irrelevant columns

# %%
data = data.drop(["iso_code","location","total_cases_per_million","new_cases_per_million","total_deaths_per_million","new_deaths_per_million",
                 "total_tests_per_thousand","new_tests_per_thousand","new_tests_smoothed_per_thousand","handwashing_facilities",
                 "gdp_per_capita","extreme_poverty","population","population_density","aged_65_older"],axis = 1)
data.head(50)
# Out:
#             date  total_cases  new_cases  total_deaths  new_deaths  \
# 8379  2019-12-31            0          0             0           0
# 8380  2020-01-01            0          0             0           0
# 8381  2020-01-02            0          0             0           0
# 8382  2020-01-03            0          0             0           0
# 8383  2020-01-04            0          0             0           0
# 8384  2020-01-05            0          0             0           0
# 8385  2020-01-06            0          0             0           0
# 8386  2020-01-07            0          0             0           0
# 8387  2020-01-08            0          0             0           0
# 8388  2020-01-09            0          0             0           0
# 8389  2020-01-10            0          0             0           0
# 8390  2020-01-11            0          0             0           0
# 8391  2020-01-12            0          0             0           0
# ...

# %% [markdown]
# ### count null values

# %%
data.isnull().sum()
# Out:
# date                       0
# total_cases                0
# new_cases                  0
# total_deaths               0
# new_deaths                 0
# total_tests               85
# new_tests                 91
# new_tests_smoothed        80
# tests_units               73
# stringency_index           1
# median_age                 0
# aged_70_older              0
# cvd_death_rate             0
# diabetes_prevalence        0
# female_smokers             0
# male_smokers               0
# hospital_beds_per_100k     0
# dtype: int64

# %% [markdown]
# # Analysis NAN Values

# %%
#using seaborn 
sns.heatmap(data.isnull(),yticklabels = False ,cmap = "viridis")

# %%
data = data[data["total_cases"] != 0]

# %%
data
# Out:
#             date  total_cases  new_cases  total_deaths  new_deaths  \
# 8409  2020-01-30            1          1             0           0
# 8410  2020-01-31            1          0             0           0
# 8411  2020-02-01            1          0             0           0
# 8412  2020-02-02            2          1             0           0
# 8413  2020-02-03            2          0             0           0
# ...          ...          ...        ...           ...         ...
# 8519  2020-05-20       106750       5611          3303         140
# 8520  2020-05-21       112359       5609          3435         132
# 8521  2020-05-22       118447       6088          3583         148
# 8522  2020-05-23       125101       6654          3720         137
# 8523  2020-05-24       131868       6767          3867         147
#
#       total_tests  new_tests  new_tests_smoothed     tests_units  \
# 8409          NaN        NaN                 NaN             NaN
# ...

# %%
data.isnull().sum()
# Out:
# date                       0
# total_cases                0
# new_cases                  0
# total_deaths               0
# new_deaths                 0
# total_tests               55
# new_tests                 61
# new_tests_smoothed        50
# tests_units               43
# stringency_index           0
# median_age                 0
# aged_70_older              0
# cvd_death_rate             0
# diabetes_prevalence        0
# female_smokers             0
# male_smokers               0
# hospital_beds_per_100k     0
# dtype: int64

# %% [markdown]
# As the all data is need to uderstand the behavior  of covid19 in India So, These missing data is no remove we just replace it with zero.

# %%
data.fillna(0,inplace = True)
data.head()
# Out:
#             date  total_cases  new_cases  total_deaths  new_deaths  \
# 8409  2020-01-30            1          1             0           0
# 8410  2020-01-31            1          0             0           0
# 8411  2020-02-01            1          0             0           0
# 8412  2020-02-02            2          1             0           0
# 8413  2020-02-03            2          0             0           0
#
#       total_tests  new_tests  new_tests_smoothed tests_units  \
# 8409          0.0        0.0                 0.0           0
# 8410          0.0        0.0                 0.0           0
# 8411          0.0        0.0                 0.0           0
# 8412          0.0        0.0                 0.0           0
# 8413          0.0        0.0                 0.0           0
#
#       stringency_index  median_age  aged_70_older  cvd_death_rate  \
# 8409             12.57        28.2          3.414          282.28
# ...

# %% [markdown]
# ## Finding the relations between the variables.

# %%
data.corr()
# Out:
#                          total_cases     new_cases  total_deaths  \
# total_cases             1.000000e+00  9.881241e-01  9.987977e-01
# new_cases               9.881241e-01  1.000000e+00  9.887789e-01
# total_deaths            9.987977e-01  9.887789e-01  1.000000e+00
# new_deaths              9.299680e-01  9.568449e-01  9.396761e-01
# total_tests             9.233612e-01  9.162664e-01  9.336210e-01
# new_tests               8.720908e-01  8.845247e-01  8.883600e-01
# new_tests_smoothed      8.950816e-01  9.102749e-01  9.118754e-01
# stringency_index        3.507493e-01  4.178046e-01  3.559238e-01
# median_age              7.625966e-17  1.192645e-15 -3.903570e-16
# aged_70_older           1.067106e-15 -5.660331e-16 -9.970501e-16
# cvd_death_rate          1.270200e-15  1.476608e-16  9.669667e-16
# diabetes_prevalence     4.853610e-16  1.402778e-15  1.237717e-16
# female_smokers         -7.362422e-16  1.997764e-16 -9.828932e-16
# ...

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.heatmap(data.corr(),annot=True,cmap = "viridis")

# %% [markdown]
# # Plot different features against one another

# %% [markdown]
# #### Total cases per day

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x = "date",y ="total_cases",data = data)

# %% [markdown]
# Total_cases per day will be parabolic increases.

# %% [markdown]
# #### Total_deaths per day

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x = "date",y ="total_deaths",data = data)

# %% [markdown]
# Total_deaths per day will be parabolic increases.

# %%
sns.set(rc={'figure.figsize':(30,20)})
sns.pairplot(data)

# %% [markdown]
# # Detecting Outliers

# %%
#using boxplot graph
sns.set(rc={'figure.figsize':(30,20)})
sns.boxplot(data= data)

# %%
def box(feature) :
    sns.set(rc={'figure.figsize':(10,8)})
    sns.boxplot(data[feature],orient = "v")

# %%
for i in data.columns:
    if i != "tests_units" :
        plt.show(box(i))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-b66b8731cdad> in <module>
#       1 for i in data.columns:
#       2     if i != "tests_units" :
# ----> 3         plt.show(box(i))
#
# <ipython-input-28-0c91f1ae6b9b> in box(feature)
#       1 def box(feature) :
#       2     sns.set(rc={'figure.figsize':(10,8)})
# ----> 3     sns.boxplot(data[feature],orient = "v")
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2239     kwargs.update(dict(whis=whis))
#    2240
# -> 2241     plotter.plot(ax, kwargs)
#    2242     return ax
#    2243
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in plot(self, ax, boxplot_kws)
#     537     def plot(self, ax, boxplot_kws):
# ...

# %% [markdown]
# total_cases ,new_cases , total_deaths ,new_deaths ,total_tests ,new_tests columns contains outilers.

# %% [markdown]
# # converting date-time to ordinal

# %%
import datetime as dt
data['date'] = pd.to_datetime(data['date']) 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 115 entries, 8409 to 8523
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   date                    115 non-null    datetime64[ns]
#  1   total_cases             115 non-null    int64
#  2   new_cases               115 non-null    int64
#  3   total_deaths            115 non-null    int64
#  4   new_deaths              115 non-null    int64
#  5   total_tests             115 non-null    float64
#  6   new_tests               115 non-null    float64
#  7   new_tests_smoothed      115 non-null    float64
#  8   tests_units             115 non-null    object
#  9   stringency_index        115 non-null    float64
#  10  median_age              115 non-null    float64
#  11  aged_70_older           115 non-null    float64
#  12  cvd_death_rate          115 non-null    float64
#  13  diabetes_prevalence     115 non-null    float64
# ...

# %%
data['date']=data['date'].map(dt.datetime.toordinal)
data.head()
# Out:
#         date  total_cases  new_cases  total_deaths  new_deaths  total_tests  \
# 8409  737454            1          1             0           0          0.0
# 8410  737455            1          0             0           0          0.0
# 8411  737456            1          0             0           0          0.0
# 8412  737457            2          1             0           0          0.0
# 8413  737458            2          0             0           0          0.0
#
#       new_tests  new_tests_smoothed tests_units  stringency_index  median_age  \
# 8409        0.0                 0.0           0             12.57        28.2
# 8410        0.0                 0.0           0             12.57        28.2
# 8411        0.0                 0.0           0             12.57        28.2
# 8412        0.0                 0.0           0             12.57        28.2
# 8413        0.0                 0.0           0             12.57        28.2
#
# ...

# %%
#Linear regression
from sklearn.model_selection import train_test_split

# %%
#getting dependent variable and inpedent variable
x = data["date"]
y = data["total_cases"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(np.array(x_train).reshape(-1,1),np.array(y_train).reshape(-1,1))
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(np.array(x_test).reshape(-1,1))

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(x_test,y_pred)
# Out:
# 518056697612.88214

# %%
lr.predict(np.array([[737573]]))
# Out:
# array([[72216.34361959]])
